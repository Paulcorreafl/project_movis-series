# %%
import pandas as pd
import numpy as np

# %%
df_films= pd.read_csv('../csv_clean/csv_clean.csv')
#df_cinema.head()
df_films
# Out:
#                        title         year certificate duration  \
# 0           Better Call Saul  (2015–2022)       TV-MA   46 min
# 1     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# 2             Grey's Anatomy     (2005– )       TV-14   41 min
# 3       The Accidental Narco     (2022– )       TV-MA   50 min
# 4                      Ozark  (2017–2022)       TV-MA   60 min
# ...                      ...          ...         ...      ...
# 4408          The Imperfects     (2022– )       TV-MA   45 min
# 4409        The Walking Dead  (2010–2022)       TV-MA   44 min
# 4410               The Crown     (2016– )       TV-MA   58 min
# 4411            Supernatural  (2005–2020)       TV-14   44 min
# 4412           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0                     Crime, Drama     8.9
# 1     Animation, Action, Adventure     8.6
# 2                   Drama, Romance     7.6
# ...

# %%
df_films.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4413 entries, 0 to 4412
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        4413 non-null   object
#  1   year         4413 non-null   object
#  2   certificate  4413 non-null   object
#  3   duration     4413 non-null   object
#  4   genre        4413 non-null   object
#  5   rating       4413 non-null   float64
#  6   description  4413 non-null   object
#  7   stars        4413 non-null   object
#  8   votes        4413 non-null   object
# dtypes: float64(1), object(8)
# memory usage: 310.4+ KB

# %%
# Eliminar todas las columnas excepto 'title' y 'year'
columnas_a_eliminar = df_films.columns.difference(['title',])
df_films.drop(columnas_a_eliminar, axis=1, inplace=True)

# %%
df_films
# Out:
#                        title
# 0           Better Call Saul
# 1     Cyberpunk: Edgerunners
# 2             Grey's Anatomy
# 3       The Accidental Narco
# 4                      Ozark
# ...                      ...
# 4408          The Imperfects
# 4409        The Walking Dead
# 4410               The Crown
# 4411            Supernatural
# 4412           Devil in Ohio
#
# [4413 rows x 1 columns]

# %%
df_films2= pd.read_csv('../data/netflix1.csv')
#df_cinema.head()
df_films2
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
# Unir las tablas por la columna 'title'
df_merged = pd.merge(df_films, df_films2, on='title', how='left')
df_merged
# Out:
#                        title show_id     type       director         country  \
# 0           Better Call Saul   s2932  TV Show      Not Given   United States
# 1     Cyberpunk: Edgerunners     NaN      NaN            NaN             NaN
# 2             Grey's Anatomy    s549  TV Show      Not Given   United States
# 3       The Accidental Narco     NaN      NaN            NaN             NaN
# 4                      Ozark   s2768  TV Show      Not Given   United States
# ...                      ...     ...      ...            ...             ...
# 4408          The Imperfects     NaN      NaN            NaN             NaN
# 4409        The Walking Dead    s391  TV Show      Not Given   United States
# 4410               The Crown   s1699  TV Show      Not Given  United Kingdom
# 4411            Supernatural   s2424  TV Show  Phil Sgriccia   United States
# 4412           Devil in Ohio     NaN      NaN            NaN             NaN
#
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4413 entries, 0 to 4412
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         4413 non-null   object
#  1   show_id       2123 non-null   object
#  2   type          2123 non-null   object
#  3   director      2123 non-null   object
#  4   country       2123 non-null   object
#  5   date_added    2123 non-null   object
#  6   release_year  2123 non-null   float64
#  7   rating        2123 non-null   object
#  8   duration      2123 non-null   object
#  9   listed_in     2123 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 344.9+ KB

# %%
df_films.to_csv('../csv_clean/csv_year.csv', index=False, encoding='utf-8')
